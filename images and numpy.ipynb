# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from PIL import Image

# %%
pic = Image.open('DATA/00-puppy.jpg')

# %%
type(pic)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
pic_array = np.asarray(pic)

# %%
type(pic_array)
# Out:
# numpy.ndarray

# %%
plt.imshow(pic_array)

# %%
pic_array.shape
# Out:
# (1300, 1950, 3)

# %%
pic_copy = pic_array.copy()

# %%
plt.imshow(pic_copy)

# %%
pic_copy.shape
# Out:
# (1300, 1950, 3)

# %%
plt.imshow(pic_copy[:,:,0],cmap='gray') #only red color

# %%
plt.imshow(pic_copy[:,:,1],cmap='gray') #only green color

# %%
plt.imshow(pic_copy[:,:,2],cmap='gray') #only blue color

# %%
pic_copy[:,:,0]=0
plt.imshow(pic_copy,cmap='gray') #no red color

# %%
pic_copy[:,:,1]=0
plt.imshow(pic_copy,cmap='gray') #no red,green color

# %%
pic_copy[:,:,2]=0
plt.imshow(pic_copy,cmap='gray') #no R,G,B color

# %%
pic_copy[:,:,2].shape
# Out:
# (1300, 1950)
